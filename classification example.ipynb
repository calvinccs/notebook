# %% [markdown]
# # Classification examples

# %%
from utils.calvin_styles import *
from utils.libs import *
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('data\mtcars.csv')
df.head()
# Out:
#                 name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
print(df.columns.tolist())
# Out:
# ['name', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']

# %%
sns.pairplot(df[['mpg','disp','hp','drat','wt','qsec','gear']], hue = 'gear')

# %%
from sklearn.datasets import load_iris

# %%
feature_names = [i.split()[0][:3] + i.split()[1] for i in iris.feature_names]
# Out:
# ['seplength', 'sepwidth', 'petlength', 'petwidth']

# %%
feature_names = [i.split()[0][:3] + i.split()[1] for i in iris.feature_names]
df = pd.DataFrame(iris.data, columns = feature_names)
df['target'] = iris.target
sns.pairplot(df, hue = 'target')

# %%
sns.plot(df[['seplength','sepwidth']])
# Out:
#      seplength  sepwidth  petlength  petwidth  target
# 0          5.1       3.5        1.4       0.2       0
# 1          4.9       3.0        1.4       0.2       0
# 2          4.7       3.2        1.3       0.2       0
# 3          4.6       3.1        1.5       0.2       0
# 4          5.0       3.6        1.4       0.2       0
# 5          5.4       3.9        1.7       0.4       0
# 6          4.6       3.4        1.4       0.3       0
# 7          5.0       3.4        1.5       0.2       0
# 8          4.4       2.9        1.4       0.2       0
# 9          4.9       3.1        1.5       0.1       0
# 10         5.4       3.7        1.5       0.2       0
# 11         4.8       3.4        1.6       0.2       0
# 12         4.8       3.0        1.4       0.1       0
# 13         4.3       3.0        1.1       0.1       0
# 14         5.8       4.0        1.2       0.2       0
# 15         5.7       4.4        1.5       0.4       0
# ...
